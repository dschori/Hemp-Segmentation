# %%
from sklearn.metrics.pairwise import euclidean_distances

def calculate_accuracy(df_prediction, df_ground_truth):
    
    GT = np.zeros((len(df_ground_truth), 2))
    PRED = np.zeros((len(df_prediction), 2))

    radius = 0.3

    for i, p_pred in enumerate(df_prediction['geometry'].centroid.values):
        for j, p_gt in enumerate(df_ground_truth['geometry'].centroid.values):
            GT[j] = (p_gt.x, p_gt.y)
            PRED[i] = (p_pred.x, p_pred.y)
            
    ds = euclidean_distances(GT, PRED)
    
    tP = sum(ds.min(axis=0)<=radius)
    tN = tP
    fN = sum(ds.min(axis=1)>radius)
    fP = ds.shape[1]-tP

    precision = tP / (tP+fP)
    recall = tP / (tP+fN)
    
    accuracy = (tP + tN) / (tP + tN + fP + fN)
    
    return precision, recall, accuracy, len(df_ground_truth), len(df_prediction)

def calculate_accuracy_old(df_prediction, df_ground_truth):
    TP = np.zeros((len(df_ground_truth), 1))
    FN = np.zeros((len(df_ground_truth), 1))
    FP = np.zeros((len(df_ground_truth), 1))

    radius = 0.3
    a = 0
    for i, p_pred in enumerate(df_prediction['geometry'].centroid.values):
        closest_distance = 1000.
        for j, p_gt in enumerate(df_ground_truth['geometry'].centroid.values):
            distance = p_pred.distance(p_gt)
            if distance < closest_distance:
                closest_distance = distance
            

    # if best_iou >= threshold it must have been a True Positive match
    if closest_distance <= radius:
        TP[i] = 1
    # if best_iou between 0.0 and threshold it must habe been False positive, because not accurate enough, but also not False Positive
    elif closest_distance < 1000.0:
        FN[i] = 1
    # if best_iou still is 0.0, it has to be a False Positive
    elif best_iou == 100.0:
        a+=1
        FP[i] = 1v vv 
    else:
        raise ValueError("Not Possible")
    print(a)

def rect_polygon(xmin, ymin, xmax, ymax):
    p = Polygon([(xmin, ymin), (xmax, ymin), (xmax, ymax), (xmin, xmax)])
    return p

# %%
import tensorflow as tf

# %%
seq_model = tf.keras.models.Sequential(name="test")

# %%
seq_model.add(tf.keras.layers.Input(shape=(28, 28, 1)))

# %%
seq_model.add(tf.keras.layers.Conv2D(1, 1))
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-18-e4ff48a882bc> in <module>
# ----> 1 seq_model.add(tf.keras.layers.Conv2D(1, 1))
#
# ~/miniconda3/envs/Smart_Farming/lib/python3.7/site-packages/tensorflow_core/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     455     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     456     try:
# --> 457       result = method(self, *args, **kwargs)
#     458     finally:
#     459       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~/miniconda3/envs/Smart_Farming/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/sequential.py in add(self, layer)
#     194       # If the model is being built continuously on top of an input layer:
#     195       # refresh its output.
# ...
